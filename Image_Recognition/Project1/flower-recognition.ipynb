# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Conv2D, Dense, MaxPooling2D, Flatten, Dropout, BatchNormalization
import cv2, warnings, random
warnings.filterwarnings('ignore')
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %%
train_dir = "../input/flower-classification/flowers/flowers/flower_photos/train/"
val_dir = "../input/flower-classification/flowers/flowers/flower_photos/validation/"
test_dir = "../input/flower-classification/flowers/flowers/flower_photos/test/"

# %%
def import_dataset(directory):
    images = []
    labels = []
    
    for category in os.listdir(directory):
        for file in os.listdir(directory+category):
            image_path = os.path.join(directory,category,file)
            image = cv2.imread(image_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image,(224,224))
            images.append(image)
            labels.append(category)
    
    images = np.array(images,dtype='float32')
    return images, labels

# %%
train_images, train_labels = import_dataset(train_dir)
valid_images, valid_labels = import_dataset(val_dir)
test_images, test_labels = import_dataset(test_dir)

# %%
train_images.shape, len(train_labels)
# Out:
# ((3540, 224, 224, 3), 3540)

# %%
sns.countplot(train_labels)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(valid_labels)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(test_labels)
# Out:
# <AxesSubplot:ylabel='count'>

# %%
def proportion(labels,dataset_type='train'):
    label_data = {'daisy': 0, 'roses': 1, 'dandelion': 2, 'sunflowers': 3, 'tulips': 4}
    plt.figure(figsize=(13,5))
    plt.title("Proportion of each Category in the {} dataset".format(dataset_type))
    plt.pie(x=pd.Series(labels).value_counts(), labels=list(label_data.keys()),  autopct='%.2f%%')
    plt.show()

# %%
proportion(train_labels)

# %%
proportion(valid_labels,'validation')

# %%
proportion(test_labels,'test')

# %%
train_images = train_images / 255.
valid_images = valid_images / 255.
test_images = test_images / 255.

# %%
encoder = LabelEncoder()
train_labels = encoder.fit_transform(train_labels)
train_labels = to_categorical(train_labels)
valid_labels = encoder.transform(valid_labels)
valid_labels = to_categorical(valid_labels)
test_labels = encoder.transform(test_labels)
test_labels = to_categorical(test_labels)

# %%
# Initializing a CNN layer
cnn = Sequential()

# 1st Convolutional Layer
cnn.add(Conv2D(filters=32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
cnn.add(MaxPooling2D(pool_size=2,strides=2))
cnn.add(BatchNormalization())

# 2nd Convolutional Layer
cnn.add(Conv2D(filters=64,kernel_size=(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())

# 3rd Convolutional Layer
cnn.add(Conv2D(filters=128,kernel_size=(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

# 4th Convolutional Layer
cnn.add(Conv2D(filters=128,kernel_size=(3,3),activation='relu'))
cnn.add(MaxPooling2D(pool_size=2))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.3))

# Flatten
cnn.add(Flatten())

# Fully Connected Layer
cnn.add(Dense(units=128,activation='relu'))
cnn.add(BatchNormalization())
cnn.add(Dropout(0.25))

# Output Layer
cnn.add(Dense(units=5,activation='softmax'))

# %%
cnn.compile(loss='categorical_crossentropy',optimizer='adam',metrics='accuracy')

# %%
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 111, 111, 32)      0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 111, 111, 32)      128
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 54, 54, 64)        256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 26, 26, 128)       512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               2359424
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 2,602,821
# Trainable params: 2,601,861
# Non-trainable params: 960
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_accuracy',patience=20,mode='max',verbose=1,restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',factor=0.1,patience=5,verbose=1,min_lr=0.001)
checkpoint_filepath = 'checkpoint/'
model_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath,monitor='val_accuracy',mode='max',save_best_only=True,verbose=1,save_weights_only=True)

r = cnn.fit(x=train_images,
            y=train_labels,
            epochs=30,
            batch_size=32,
            validation_data=(valid_images,valid_labels),
            callbacks=[early_stopping,reduce_lr,model_checkpoint])
# Out:
# Epoch 1/30
# 111/111 [==============================] - 5s 34ms/step - loss: 1.2812 - accuracy: 0.5302 - val_loss: 4.2984 - val_accuracy: 0.2000
#
# Epoch 00001: val_accuracy improved from -inf to 0.20000, saving model to checkpoint/
# Epoch 2/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.9083 - accuracy: 0.6627 - val_loss: 2.5763 - val_accuracy: 0.2000
#
# Epoch 00002: val_accuracy did not improve from 0.20000
# Epoch 3/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.7968 - accuracy: 0.7042 - val_loss: 1.9651 - val_accuracy: 0.3250
#
# Epoch 00003: val_accuracy improved from 0.20000 to 0.32500, saving model to checkpoint/
# Epoch 4/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.6465 - accuracy: 0.7621 - val_loss: 1.6683 - val_accuracy: 0.4500
#
# Epoch 00004: val_accuracy improved from 0.32500 to 0.45000, saving model to checkpoint/
# Epoch 5/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.5805 - accuracy: 0.7884 - val_loss: 0.9905 - val_accuracy: 0.6125
#
# Epoch 00005: val_accuracy improved from 0.45000 to 0.61250, saving model to checkpoint/
# Epoch 6/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.4496 - accuracy: 0.8395 - val_loss: 0.9558 - val_accuracy: 0.6875
#
# Epoch 00006: val_accuracy improved from 0.61250 to 0.68750, saving model to checkpoint/
# Epoch 7/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.3977 - accuracy: 0.8616 - val_loss: 0.9375 - val_accuracy: 0.7125
#
# Epoch 00007: val_accuracy improved from 0.68750 to 0.71250, saving model to checkpoint/
# Epoch 8/30
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2947 - accuracy: 0.8969 - val_loss: 1.3325 - val_accuracy: 0.6375
#
# Epoch 00008: val_accuracy did not improve from 0.71250
# Epoch 9/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2406 - accuracy: 0.9175 - val_loss: 0.9435 - val_accuracy: 0.6625
#
# Epoch 00009: val_accuracy did not improve from 0.71250
# Epoch 10/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1958 - accuracy: 0.9345 - val_loss: 0.8471 - val_accuracy: 0.7375
#
# Epoch 00010: val_accuracy improved from 0.71250 to 0.73750, saving model to checkpoint/
# Epoch 11/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1485 - accuracy: 0.9525 - val_loss: 1.0729 - val_accuracy: 0.7000
#
# Epoch 00011: val_accuracy did not improve from 0.73750
# Epoch 12/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1146 - accuracy: 0.9650 - val_loss: 0.9558 - val_accuracy: 0.7250
#
# Epoch 00012: val_accuracy did not improve from 0.73750
# Epoch 13/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1290 - accuracy: 0.9562 - val_loss: 1.3893 - val_accuracy: 0.6500
#
# Epoch 00013: val_accuracy did not improve from 0.73750
# Epoch 14/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1080 - accuracy: 0.9703 - val_loss: 1.0694 - val_accuracy: 0.7125
#
# Epoch 00014: val_accuracy did not improve from 0.73750
# Epoch 15/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0875 - accuracy: 0.9718 - val_loss: 1.1253 - val_accuracy: 0.6750
#
# Epoch 00015: val_accuracy did not improve from 0.73750
# Epoch 16/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0853 - accuracy: 0.9746 - val_loss: 0.8727 - val_accuracy: 0.7250
#
# Epoch 00016: val_accuracy did not improve from 0.73750
# Epoch 17/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0556 - accuracy: 0.9856 - val_loss: 0.9352 - val_accuracy: 0.7625
#
# Epoch 00017: val_accuracy improved from 0.73750 to 0.76250, saving model to checkpoint/
# Epoch 18/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0637 - accuracy: 0.9805 - val_loss: 1.3109 - val_accuracy: 0.6750
#
# Epoch 00018: val_accuracy did not improve from 0.76250
# Epoch 19/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0600 - accuracy: 0.9816 - val_loss: 1.0898 - val_accuracy: 0.7250
#
# Epoch 00019: val_accuracy did not improve from 0.76250
# Epoch 20/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0659 - accuracy: 0.9797 - val_loss: 1.1981 - val_accuracy: 0.7125
#
# Epoch 00020: val_accuracy did not improve from 0.76250
# Epoch 21/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0543 - accuracy: 0.9845 - val_loss: 1.2967 - val_accuracy: 0.6625
#
# Epoch 00021: val_accuracy did not improve from 0.76250
# Epoch 22/30
# 111/111 [==============================] - 3s 32ms/step - loss: 0.0541 - accuracy: 0.9814 - val_loss: 0.9874 - val_accuracy: 0.7375
#
# Epoch 00022: val_accuracy did not improve from 0.76250
# Epoch 23/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0648 - accuracy: 0.9780 - val_loss: 1.1746 - val_accuracy: 0.7125
#
# Epoch 00023: val_accuracy did not improve from 0.76250
# Epoch 24/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0815 - accuracy: 0.9743 - val_loss: 1.2699 - val_accuracy: 0.7875
#
# Epoch 00024: val_accuracy improved from 0.76250 to 0.78750, saving model to checkpoint/
# Epoch 25/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0616 - accuracy: 0.9785 - val_loss: 1.3257 - val_accuracy: 0.7000
#
# Epoch 00025: val_accuracy did not improve from 0.78750
# Epoch 26/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0488 - accuracy: 0.9842 - val_loss: 1.2255 - val_accuracy: 0.7500
#
# Epoch 00026: val_accuracy did not improve from 0.78750
# Epoch 27/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0507 - accuracy: 0.9867 - val_loss: 1.0710 - val_accuracy: 0.7500
#
# Epoch 00027: val_accuracy did not improve from 0.78750
# Epoch 28/30
# 111/111 [==============================] - 4s 32ms/step - loss: 0.0549 - accuracy: 0.9856 - val_loss: 1.1159 - val_accuracy: 0.7375
#
# Epoch 00028: val_accuracy did not improve from 0.78750
# Epoch 29/30
# 111/111 [==============================] - 3s 31ms/step - loss: 0.0372 - accuracy: 0.9881 - val_loss: 1.1260 - val_accuracy: 0.7125
#
# Epoch 00029: val_accuracy did not improve from 0.78750
# Epoch 30/30
# 111/111 [==============================] - 4s 32ms/step - loss: 0.0404 - accuracy: 0.9876 - val_loss: 1.0759 - val_accuracy: 0.7500
#
# Epoch 00030: val_accuracy did not improve from 0.78750

# %%
cnn.load_weights(checkpoint_filepath)

# %%
plt.figure(figsize=(12,8))
plt.plot(r.history['loss'],'r',label='train loss')
plt.plot(r.history['val_loss'],'b',label='validation loss')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.title('Loss Graph')
plt.legend();

# %%
plt.figure(figsize=(12,8))
plt.plot(r.history['accuracy'],'r',label='train accuracy')
plt.plot(r.history['val_accuracy'],'b',label='validation accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy Graph')
plt.legend();

# %%
test_pred = cnn.predict(test_images)

# %%
print("Accuracy Score:", str(int(np.sum(np.argmax(test_labels,axis=1) == np.argmax(test_pred,axis=1)) / len(test_labels) * 100)) + '%')
# Out:
# Accuracy Score: 64%

# %%
img_idx = random.randint(0,len(test_images))
print("Original Label:", encoder.inverse_transform([np.argmax(test_labels[img_idx])])[0])
pred = cnn.predict(test_images[img_idx].reshape(1,224,224,3))
predicted_label = encoder.inverse_transform([pred.argmax()])[0]
print("Predicted Label:", predicted_label)
plt.imshow(test_images[img_idx]);
# Out:
# Original Label: tulips
# Predicted Label: tulips

# %%
img_idx = 32
print("Original Label:", encoder.inverse_transform([np.argmax(test_labels[img_idx])])[0])
pred = cnn.predict(test_images[img_idx].reshape(1,224,224,3))
predicted_label = encoder.inverse_transform([pred.argmax()])[0]
print("Predicted Label:", predicted_label)
plt.imshow(test_images[img_idx]);
# Out:
# Original Label: roses
# Predicted Label: roses
